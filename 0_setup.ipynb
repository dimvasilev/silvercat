# %% [markdown]
# <a href="https://colab.research.google.com/github/dimvasilev/silvercat/blob/main/0_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Overview
#
# This notebook tackles the Analytics section of the task.
#
# It addressess the following considerations:

# %%
# %cd /content
# !rm -rf silvercat
# !git clone https://github.com/dimvasilev/silvercat.git
# %cd /content/silvercat

# %pip install -r requirements.txt
# %pip install -e .
# Out:
# /content
# Cloning into 'silvercat'...
# remote: Enumerating objects: 43, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 43 (delta 11), reused 37 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (43/43), 242.14 KiB | 24.21 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# /content/silvercat
# ...
# Obtaining file:///content/silvercat
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for silvercat (pyproject.toml) ... done
#   Created wheel for silvercat: filename=silvercat-0.1.0-py3-none-any.whl size=1536 sha256=8dbc7ad0764716e77f283f59b062420143791ed09023dffa7559a6a77882bf79
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2vl3bk7w/wheels/55/be/60/a954dffebfb7921515cb243b35c80dafe8d6e6dfecba2c6885
# ...

# %%
from silvercat.utils import setup

import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
paths = setup()
# Out:
# Using Colab cache for faster access to the 'lending-club' dataset.
# Successfully copied Lending Club files to /content/silvercat/data
# Project root: /content/silvercat
# Data directory: /content/silvercat/data
# Accepted data exists: True
# Rejected data exists: True
# Data dictionary exists: True

# %%
import pandas as pd

accepts_sample = pd.read_csv(paths.accepts, nrows=100_000)
accepts_sample.head()
# Out:
# /tmp/ipykernel_30165/3318187345.py:3: DtypeWarning: Columns (0: desc) have mixed types. Specify dtype option on import or set low_memory=False.
#   accepts_sample = pd.read_csv(paths.accepts, nrows=100_000)
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# ...

# %%
# !git config user.name "dimvasilev"
# !git config user.email "vasilev.dimitar@gmail.com"

# %%
# !git status
# !git add src/silvercat/utils.py
# !git commit -m "Add project setup helper"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   src/silvercat/utils.py
#
# [main c745767] Add project setup helper
#  1 file changed, 67 insertions(+), 14 deletions(-)
#  rewrite src/silvercat/utils.py (82%)

# %%
from google.colab import userdata

token = userdata.get("silvercat")

# !git remote set-url origin https://{token}@github.com/dimvasilev/silvercat.git
# !git push origin main
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 1.03 KiB | 1.03 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/dimvasilev/silvercat.git
#    df324b6..c745767  main -> main

# %%
import importlib
import silvercat.utils as utils

importlib.reload(utils)
